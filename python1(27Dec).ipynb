# %%
100
#this is just a number nothing else(comments)
# Out:
# 100

# %% [markdown]
# How to excecute a cell via keyboard:
#
#
# 1.   ctrl + enter only run the active cell
# 2.   ctrl + shift runs the active cell and add a new cell also.

# %% [markdown]
# What is a language?
