# %% [markdown]
# **Topics Covered: **
# Print function,
# Data Types
#  and Variables

# %%
print("Hello Python Developer")
# Out:
# Hello Python Developer

# %%
print("Pakistan Zindabad")
print(2,3)
# Out:
# Pakistan Zindabad
# 2 3

# %%
print(2+3)
# Out:
# 5

# %%
print("smit", "saylani")
# Out:
# smit saylani

# %%
print(2)
print()
print("SMIT")
# Out:
# 2
#
# SMIT

# %% [markdown]
# **Print**
# Print is a python function (action) that print the value given on the console. The value given to print (function) is called argument.

# %%
print("argument1", "argument2")
# Out:
# argument1 argument2

# %%
print("argument1", "argument2", "argument3")
# Out:
# argument1 argument2 argument3

# %%
print("argument1",      "argument2", "argument3",4,5,6) #sep=' '
# Out:
# argument1 argument2 argument3 4 5 6

# %% [markdown]
# Possible argument in a print function:
# numbers, alphabets, function, boolean

# %% [markdown]
# **Signature:**
# ctrl + spacebar

# %%
print() #end # sep

# %%
print(2,2,3,3, sep = ">>")
# Out:
# 2>>2>>3>>3

# %%
print("Osama", "shakeel", sep = ">>") #technically known as over-rinding
# Out:
# Osama>>shakeel

# %%
print("Pakistan") # end='\n'
print("Afghanistan")
print("India")
# Out:
# Pakistan
# Afghanistan
# India

# %% [markdown]
# (*values: object, sep: str | None = ..., end: str | None = ..., file: SupportsWrite[str] | None = ..., flush: bool = ...) -> None
#
#
# **print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)**
#
# Prints the values to a stream, or to sys.stdout by default.
# Optional keyword arguments:
# file:  a file-like object (stream); defaults to the current sys.stdout.
# sep:   string inserted between values, default a space.
# end:   string appended after the last value, default a newline.
# flush: whether to forcibly flush the stream.

# %%
print("Pakistan", end = "") # escape character /n >>> newline
print("Afghanistan" , end = "")
print("India", end = "")
print("Usa", end = "")
# Out:
# PakistanAfghanistanIndiaUsa

# %%
print("Pakistan", end = "") # escape character /n >>> newline
print("Afghanistan" , end = "\n")
print("India", end = "")
print("Usa", end = "")
# Out:
# PakistanAfghanistan
# IndiaUsa

# %%
print("we are the \nlearner of  \nPython")
# Out:
# we are the
# learner of
# Python

# %% [markdown]
# **Escape Character** How many escape character are there in Python?

# %%
print("Pakistan", end = "\t") # escape character \t >>> tab
print("Afghanistan" , end = "\t")
print("India", end = "\t")
print("Usa", end = "")
# Out:
# Pakistan	Afghanistan	India	Usa

# %%
print("we are the \tlearner of  \tPython")
# Out:
# we are the 	learner of  	Python

# %%
txt = "We are the so-called \"Vikings\" from the north." # escape character \

# %%
print(txt)
# Out:
# We are the so-called "Vikings" from the north.

# %%
"""
\   Escape Character
\'	Single Quote	
\\	Backslash	
\n	New Line	
\r	Carriage Return	
\t	Tab	
\b	Backspace	
\f	Form Feed	
\ooo	Octal value	
\xhh	Hex value
"""

# %%
print("we are the \'learner of  \'Python") # Single Quote	=  \'
# Out:
# we are the 'learner of  'Python

# %% [markdown]
# In Python strings, the backslash "\" is a special character, also called the "escape" character. It is used in representing certain whitespace characters

# %%
print('It\'s raining')
# Out:
# It's raining

# %% [markdown]
# Conversely, prefixing a special character with "\" turns it into an ordinary character. This is called "escaping". For example, "\'" is the single quote character. 'It\'s raining' therefore is a valid string and equivalent to "It's raining". Likewise, '"' can be escaped: "\"hello\"" is a string begins and ends with the literal double quote character. Finally, "\" can be used to escape itself: "\\" is the literal backslash character.

# %%
print("\"hello\"")
# Out:
# "hello"

# %%
print('"\\" is the backslash')
# Out:
# "\" is the backslash

# %%
print("we are the \rlearner of  \rPython") # Carriage Return =  \r
# Out:
# Python

# %%
print("we \r sref")
# Out:
#  sref

# %%
print("we are the learner of  \rPython")
# Out:
# Python

# %%
print("we are the \rlearner of  Python")
# Out:
# learner of  Python

# %%
print("we are the \blearner of  Python")   # Backspace = \b
# Out:
# learner of  Python

# %%
print("we \b sref")
# Out:
#  sref

# %%
print("we\b sref")
# Out:
#  sref

# %%
print('my name is "Osama" ')
print("my name is 'Osama' ")
# Out:
# my name is "Osama"
# my name is 'Osama'

# %% [markdown]
# **2. DataTypes:**
#
# Numbers and Characters
#
# **Numbers:**
# Whole Numbers (integers)
# Decimals (Floating numbers)
#
# **Integers:** = 2,3,-4,-2,-7
#  ** Float** = 2.3, 6.7
#
# **Characters:**
# Strings (usually represented by '' or "")
#
# **Boolean:**
# True
# Flase

# %%
print("This is string") # string
print(100)              # integers
print(20.0)             # decimals
print(True)             # Boolean
print(False)            # Boolean
# Out:
# This is string
# 100
# 20.0
# True
# False

# %%
print("This is string", 100,   20.0,   True,   False)
    #   string          int   #float   #bool    #bool
# Out:
# This is string 100 20.0 True False

# %%
print('this is a string')
# Out:
# this is a string

# %%
# This is my friend's book
print('This is my friend\'s book')
# Out:
# This is my friend's book

# %%
# This is my friend's book
print("This is my friend's book")
# Out:
# This is my friend's book

# %%
print("he said \"runaway\" ")
# Out:
# he said "runaway"

# %%
print("This is \"python\" programing langauge") # \ escape character
# Out:
# This is "python" programing langauge

# %% [markdown]
# **3. Variables:**
# vary >> change >> increse >> decrease
#
# **Real world Quantities:** Age, Height, Weight, Date, Days
# Changeable quantities are called Variable

# %%
#Variable is a identitifier

# %%
#Variable = Container

# %%
#creating a variable and assigning a variable

age = 50    # int 50 is assigned to var age

# variable name is age
# variable value is 50 
# variable Value Type is integer (int)
# this code is read as >> int 50 is assigned to a variable whose name (identifier) is age
# "=" is an operator called assignement operator

# %%
type(age)
# Out:
# int

# %%
age = 50.6    # float 50.6 is assigned to var age

# %%
type(age)
# Out:
# float

# %%
age = "Hello"

# %%
type(age)
# Out:
# str

# %%
# integer variable
marks = 90

# float variable
per = 90.6

# string variable
college = "SMIT"

# Boolean variable
exampass = True
feespaid = False

# %%
print(type(marks), type(per), type(college), type(exampass) ,type(feespaid))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'> <class 'bool'>

# %%
print(marks)
# Out:
# 90

# %%
# Checking memory address of variable
id(marks)
# Out:
# 94842652607776

# %%
marks = 900

# %%
print(marks) # it isn't string, it is name of variable
# the name of variable will not be in quotation
# Out:
# 900

# %%
# Checking memory address of variable
id(marks)
# Out:
# 139668457546000

# %% [markdown]
# 90 or 900 is like the one who is living in the house, Variable is like the house owner name, and address(id) is like house number in which 90 or 900 is living
